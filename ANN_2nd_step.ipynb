# %% [markdown]
# <a href="https://colab.research.google.com/github/gundaminpde/2023_F_set_theory/blob/main/ANN_2nd_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 전처리**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

### from sklearn.neighbors import KNeighborsClassifier

Url_B_cancer="https://raw.githubusercontent.com/gundaminpde/2023-spring/main/Dset_Breast%20Cancer_Wisconsin.csv"


df = pd.read_csv(Url_B_cancer)

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# Attribute Information:
#
# * Diagnosis (M = malignant, B = benign)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df=df.drop(['id',"Unnamed: 32"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %%
y_original = df['diagnosis']

# %%
y_original.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
y_original_2=pd.get_dummies(y_original)

y_original_2.head()
# Out:
#    B  M
# 0  0  1
# 1  0  1
# 2  0  1
# 3  0  1
# 4  0  1

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:,1:], y_original_2['B'],stratify=y_original_2['B'], random_state=3)

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 281       11.740         14.02           74.24      427.3          0.07813
# 78        20.180         23.97          143.70     1245.0          0.12860
# 248       10.650         25.22           68.01      347.0          0.09657
# 120       11.410         10.82           73.34      403.3          0.09373
# 539        7.691         25.44           48.34      170.4          0.08668
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 281           0.04340         0.02245              0.02763         0.2101
# 78            0.34540         0.37540              0.16040         0.2906
# 248           0.07234         0.02379              0.01615         0.1897
# 120           0.06685         0.03512              0.02623         0.1667
# 539           0.11990         0.09252              0.01364         0.2037
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 281                 0.06113  ...        13.310          18.26
# 78                  0.08142  ...        23.370          31.72
# 248                 0.06329  ...        12.250          35.19
# 120                 0.06113  ...        12.820          15.97
# 539                 0.07751  ...         8.678          31.89
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 281            84.70       533.7            0.1036             0.0850
# 78            170.30      1623.0            0.1639             0.6164
# 248            77.98       455.7            0.1499             0.1398
# 120            83.74       510.5            0.1548             0.2390
# 539            54.49       223.6            0.1596             0.3064
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 281          0.06735               0.08290          0.3101
# 78           0.76810               0.25080          0.5440
# 248          0.11250               0.06136          0.3409
# 120          0.21020               0.08958          0.3016
# 539          0.33930               0.05000          0.2790
#
#      fractal_dimension_worst
# 281                  0.06688
# 78                   0.09964
# 248                  0.08147
# 120                  0.08523
# 539                  0.10660
#
# [5 rows x 30 columns]

# %%
std = StandardScaler()
std.fit(X_train.iloc[:,0:])
X_train.iloc[:,0:]= std.transform(X_train.iloc[:,0:])
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 281    -0.671799     -1.230238       -0.723020  -0.642037        -1.279838
# 78      1.743377      1.080998        2.155806   1.706229         2.313272
# 248    -0.983712      1.371354       -0.981228  -0.872642         0.032961
# 120    -0.766231     -1.973550       -0.760321  -0.710960        -0.169227
# 539    -1.830454      1.422457       -1.796467  -1.379801        -0.671138
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 281         -1.144226       -0.832219            -0.540062       1.064630
# 78           4.626903        3.669741             2.929992       3.990013
# 248         -0.591192       -0.815127            -0.840101       0.323291
# 120         -0.696104       -0.670610            -0.576652      -0.512533
# 539          0.317666        0.061541            -0.905702       0.832053
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 281               -0.213870  ...     -0.603031      -1.210885
# 78                 2.682433  ...      1.508085       0.993413
# 248                0.094460  ...     -0.825474       1.561683
# 120               -0.213870  ...     -0.705858      -1.585910
# 539                2.124299  ...     -1.575067       1.021254
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 281        -0.660779   -0.598653         -1.243058          -1.069445
# 78          1.917078    1.343444          1.400349           2.347860
# 248        -0.863152   -0.737718          0.786623          -0.717039
# 120        -0.689689   -0.640016          1.001427          -0.079108
# 539        -1.570557   -1.151526          1.211847           0.354325
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 281        -0.987536             -0.477389        0.329329
# 78          2.442924              2.111273        4.074589
# 248        -0.766508             -0.809490        0.822506
# 120        -0.288227             -0.374398        0.193225
# 539         0.343771             -0.984637       -0.168651
#
#      fractal_dimension_worst
# 281                -0.933254
# 78                  0.910914
# 248                -0.111935
# 120                 0.099728
# 539                 1.302715
#
# [5 rows x 30 columns]

# %%
X_test.iloc[:,0:]= std.transform(X_test.iloc[:,0:])

# %%
X_test.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 373     1.875010     -0.456729        1.786938   1.964691        -0.117256
# 101    -2.033627     -1.367286       -1.985045  -1.457052         1.487434
# 187    -0.680384     -0.493895       -0.704784  -0.662139         0.116257
# 480    -0.551613     -0.298775       -0.555165  -0.561626        -0.372839
# 191    -0.377056      0.486348       -0.400572  -0.412006        -0.613471
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 373          0.082616        0.829151             1.074610      -0.861398
# 101         -0.527365       -1.118574            -1.262195       0.443213
# 187         -0.800061       -0.632727            -0.415655      -1.061269
# 480         -0.475769       -0.746631            -0.863101      -1.250238
# 191         -0.712156       -0.721631            -0.513665      -0.414414
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 373               -1.120303  ...      1.927790      -0.406791
# 101                2.219938  ...     -1.732037      -1.001263
# 187               -0.239564  ...     -0.665986      -0.698295
# 480                0.030224  ...     -0.596735       0.362912
# 191                0.034507  ...     -0.510696      -0.352748
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 373         1.811675    1.919316          1.062799           0.348537
# 101        -1.693427   -1.219988          1.159242          -0.843082
# 187        -0.669211   -0.620404          0.015081          -0.947261
# 480        -0.536403   -0.574227         -0.489052          -0.150490
# 191        -0.530079   -0.516997         -1.669160          -1.038706
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 373         0.718759              1.500725       -0.330374
# 101        -1.317242             -1.755531        0.058723
# 187        -0.572650             -0.061106       -0.517717
# 480        -0.524186             -0.878254       -0.783520
# 191        -1.063366             -1.019636       -1.146998
#
#      fractal_dimension_worst
# 373                -0.726658
# 101                 0.583287
# 187                -0.703014
# 480                -0.347241
# 191                -0.830237
#
# [5 rows x 30 columns]

# %%
y_train.describe()
# Out:
# count    426.000000
# mean       0.626761
# std        0.484234
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: B, dtype: float64

# %%
y_test.describe()
# Out:
# count    143.000000
# mean       0.629371
# std        0.484671
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: B, dtype: float64

# %%
df_cat = pd.concat([X_train,y_train], axis=1)

corr_mat=np.corrcoef(df_cat,rowvar=False)

sns.heatmap(corr_mat,linewidth=1,cmap='RdYlGn_r')
plt.show()

# %% [markdown]
# **채색의 종류**
#
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
df_cat.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 281    -0.671799     -1.230238       -0.723020  -0.642037        -1.279838
# 78      1.743377      1.080998        2.155806   1.706229         2.313272
# 248    -0.983712      1.371354       -0.981228  -0.872642         0.032961
# 120    -0.766231     -1.973550       -0.760321  -0.710960        -0.169227
# 539    -1.830454      1.422457       -1.796467  -1.379801        -0.671138
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 281         -1.144226       -0.832219            -0.540062       1.064630
# 78           4.626903        3.669741             2.929992       3.990013
# 248         -0.591192       -0.815127            -0.840101       0.323291
# 120         -0.696104       -0.670610            -0.576652      -0.512533
# 539          0.317666        0.061541            -0.905702       0.832053
#
#      fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 281               -0.213870  ...      -1.210885        -0.660779   -0.598653
# 78                 2.682433  ...       0.993413         1.917078    1.343444
# 248                0.094460  ...       1.561683        -0.863152   -0.737718
# 120               -0.213870  ...      -1.585910        -0.689689   -0.640016
# 539                2.124299  ...       1.021254        -1.570557   -1.151526
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 281         -1.243058          -1.069445        -0.987536
# 78           1.400349           2.347860         2.442924
# 248          0.786623          -0.717039        -0.766508
# 120          1.001427          -0.079108        -0.288227
# 539          1.211847           0.354325         0.343771
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  B
# 281             -0.477389        0.329329                -0.933254  1
# 78               2.111273        4.074589                 0.910914  0
# 248             -0.809490        0.822506                -0.111935  1
# 120             -0.374398        0.193225                 0.099728  1
# 539             -0.984637       -0.168651                 1.302715  1
#
# [5 rows x 31 columns]

# %%
X_train.shape
# Out:
# (426, 30)

# %% [markdown]
# # **1. 기본적인 모델**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model = Sequential()                                                  # 딥러닝 모델의 구조를 결정합니다.
model.add(Dense(30, input_dim=30, activation='relu'))
model.add(Dense(20, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])  # 딥러닝 모델을 실행합니다.

history=model.fit(X_train, y_train, epochs=70, batch_size=16)
# Out:
# Epoch 1/70
# 27/27 [==============================] - 1s 3ms/step - loss: 0.5696 - binary_accuracy: 0.7183
# Epoch 2/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4143 - binary_accuracy: 0.8967
# Epoch 3/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3021 - binary_accuracy: 0.9296
# Epoch 4/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2261 - binary_accuracy: 0.9343
# Epoch 5/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1782 - binary_accuracy: 0.9484
# Epoch 6/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1469 - binary_accuracy: 0.9624
# Epoch 7/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1243 - binary_accuracy: 0.9742
# Epoch 8/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1092 - binary_accuracy: 0.9859
# Epoch 9/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0975 - binary_accuracy: 0.9883
# Epoch 10/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0886 - binary_accuracy: 0.9883
# Epoch 11/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0822 - binary_accuracy: 0.9859
# Epoch 12/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0768 - binary_accuracy: 0.9883
# Epoch 13/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0726 - binary_accuracy: 0.9859
# Epoch 14/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0694 - binary_accuracy: 0.9883
# Epoch 15/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0663 - binary_accuracy: 0.9859
# Epoch 16/70
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0631 - binary_accuracy: 0.9883
# Epoch 17/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0606 - binary_accuracy: 0.9883
# Epoch 18/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0589 - binary_accuracy: 0.9883
# Epoch 19/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0571 - binary_accuracy: 0.9859
# Epoch 20/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0544 - binary_accuracy: 0.9906
# Epoch 21/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0527 - binary_accuracy: 0.9883
# Epoch 22/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0509 - binary_accuracy: 0.9906
# Epoch 23/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0488 - binary_accuracy: 0.9906
# Epoch 24/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0473 - binary_accuracy: 0.9906
# Epoch 25/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0454 - binary_accuracy: 0.9906
# Epoch 26/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0436 - binary_accuracy: 0.9906
# Epoch 27/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0422 - binary_accuracy: 0.9906
# Epoch 28/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0404 - binary_accuracy: 0.9906
# Epoch 29/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0392 - binary_accuracy: 0.9906
# Epoch 30/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0371 - binary_accuracy: 0.9906
# Epoch 31/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0355 - binary_accuracy: 0.9906
# Epoch 32/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0338 - binary_accuracy: 0.9906
# Epoch 33/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0321 - binary_accuracy: 0.9930
# Epoch 34/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0302 - binary_accuracy: 0.9930
# Epoch 35/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0290 - binary_accuracy: 0.9930
# Epoch 36/70
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0275 - binary_accuracy: 0.9930
# Epoch 37/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0260 - binary_accuracy: 0.9930
# Epoch 38/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0250 - binary_accuracy: 0.9930
# Epoch 39/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0236 - binary_accuracy: 0.9930
# Epoch 40/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0226 - binary_accuracy: 0.9930
# Epoch 41/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0220 - binary_accuracy: 0.9977
# Epoch 42/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0203 - binary_accuracy: 0.9977
# Epoch 43/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0201 - binary_accuracy: 0.9953
# Epoch 44/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0188 - binary_accuracy: 0.9977
# Epoch 45/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0181 - binary_accuracy: 0.9977
# Epoch 46/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0170 - binary_accuracy: 0.9977
# Epoch 47/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0166 - binary_accuracy: 0.9977
# Epoch 48/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0157 - binary_accuracy: 0.9977
# Epoch 49/70
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0151 - binary_accuracy: 0.9977
# Epoch 50/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0142 - binary_accuracy: 0.9977
# Epoch 51/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0136 - binary_accuracy: 1.0000
# Epoch 52/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0131 - binary_accuracy: 1.0000
# Epoch 53/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0125 - binary_accuracy: 1.0000
# Epoch 54/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0121 - binary_accuracy: 1.0000
# Epoch 55/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0114 - binary_accuracy: 1.0000
# Epoch 56/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0113 - binary_accuracy: 1.0000
# Epoch 57/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0110 - binary_accuracy: 1.0000
# Epoch 58/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0104 - binary_accuracy: 1.0000
# Epoch 59/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0098 - binary_accuracy: 1.0000
# Epoch 60/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0092 - binary_accuracy: 1.0000
# Epoch 61/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0090 - binary_accuracy: 1.0000
# Epoch 62/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0088 - binary_accuracy: 1.0000
# Epoch 63/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0083 - binary_accuracy: 1.0000
# Epoch 64/70
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0081 - binary_accuracy: 1.0000
# Epoch 65/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0077 - binary_accuracy: 1.0000
# Epoch 66/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0075 - binary_accuracy: 1.0000
# Epoch 67/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0070 - binary_accuracy: 1.0000
# Epoch 68/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0068 - binary_accuracy: 1.0000
# Epoch 69/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0066 - binary_accuracy: 1.0000
# Epoch 70/70
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0062 - binary_accuracy: 1.0000

# %%
y_loss = history.history['loss']
y_accu = history.history['binary_accuracy']

x_len = np.arange(len(y_loss))

plt.plot(x_len,y_loss)
plt.plot(x_len,y_accu, marker='.', c="red")

plt.show()

# %%
A=X_test.iloc[3,0:].to_numpy()

# %%
B=A.reshape(1, 30)

# %%
model.predict(B,verbose=0)#[:10]
# Out:
# array([[0.999382]], dtype=float32)

# %%
model.predict(X_test,verbose=0)[:10]
# Out:
# array([[0.00238198],
#        [0.9996238 ],
#        [0.9994433 ],
#        [0.999382  ],
#        [0.96139354],
#        [0.94413084],
#        [0.9972222 ],
#        [0.00238196],
#        [0.3203216 ],
#        [0.00238191]], dtype=float32)

# %% [markdown]
# # **2. Validation set을 사용하여 과적합 확인**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import random

random.seed(5)

model = Sequential()                                                  # 딥러닝 모델의 구조를 결정합니다.
model.add(Dense(30, input_dim=30, activation='relu'))
model.add(Dense(20, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])  # 딥러닝 모델을 실행합니다.

history=model.fit(X_train, y_train, validation_split=0.25, epochs=70, batch_size=16, verbose=1)
# Out:
# Epoch 1/70
# 20/20 [==============================] - 1s 9ms/step - loss: 0.8526 - binary_accuracy: 0.3887 - val_loss: 0.7870 - val_binary_accuracy: 0.3271
# Epoch 2/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6627 - binary_accuracy: 0.4232 - val_loss: 0.6022 - val_binary_accuracy: 0.6449
# Epoch 3/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5189 - binary_accuracy: 0.7931 - val_loss: 0.4642 - val_binary_accuracy: 0.9159
# Epoch 4/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4105 - binary_accuracy: 0.9310 - val_loss: 0.3734 - val_binary_accuracy: 0.9533
# Epoch 5/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3353 - binary_accuracy: 0.9498 - val_loss: 0.3127 - val_binary_accuracy: 0.9533
# Epoch 6/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2823 - binary_accuracy: 0.9592 - val_loss: 0.2708 - val_binary_accuracy: 0.9533
# Epoch 7/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2440 - binary_accuracy: 0.9655 - val_loss: 0.2406 - val_binary_accuracy: 0.9533
# Epoch 8/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2157 - binary_accuracy: 0.9655 - val_loss: 0.2170 - val_binary_accuracy: 0.9533
# Epoch 9/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1925 - binary_accuracy: 0.9687 - val_loss: 0.1998 - val_binary_accuracy: 0.9626
# Epoch 10/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1745 - binary_accuracy: 0.9749 - val_loss: 0.1853 - val_binary_accuracy: 0.9720
# Epoch 11/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1598 - binary_accuracy: 0.9749 - val_loss: 0.1731 - val_binary_accuracy: 0.9626
# Epoch 12/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1471 - binary_accuracy: 0.9749 - val_loss: 0.1628 - val_binary_accuracy: 0.9626
# Epoch 13/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1364 - binary_accuracy: 0.9812 - val_loss: 0.1544 - val_binary_accuracy: 0.9626
# Epoch 14/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1273 - binary_accuracy: 0.9812 - val_loss: 0.1470 - val_binary_accuracy: 0.9626
# Epoch 15/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1191 - binary_accuracy: 0.9843 - val_loss: 0.1403 - val_binary_accuracy: 0.9626
# Epoch 16/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1117 - binary_accuracy: 0.9843 - val_loss: 0.1358 - val_binary_accuracy: 0.9626
# Epoch 17/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1056 - binary_accuracy: 0.9843 - val_loss: 0.1318 - val_binary_accuracy: 0.9626
# Epoch 18/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0997 - binary_accuracy: 0.9843 - val_loss: 0.1281 - val_binary_accuracy: 0.9626
# Epoch 19/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0948 - binary_accuracy: 0.9843 - val_loss: 0.1238 - val_binary_accuracy: 0.9720
# Epoch 20/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0899 - binary_accuracy: 0.9875 - val_loss: 0.1220 - val_binary_accuracy: 0.9720
# Epoch 21/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0859 - binary_accuracy: 0.9875 - val_loss: 0.1208 - val_binary_accuracy: 0.9720
# Epoch 22/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0819 - binary_accuracy: 0.9875 - val_loss: 0.1187 - val_binary_accuracy: 0.9720
# Epoch 23/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0782 - binary_accuracy: 0.9875 - val_loss: 0.1172 - val_binary_accuracy: 0.9720
# Epoch 24/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0748 - binary_accuracy: 0.9875 - val_loss: 0.1168 - val_binary_accuracy: 0.9720
# Epoch 25/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0718 - binary_accuracy: 0.9906 - val_loss: 0.1147 - val_binary_accuracy: 0.9720
# Epoch 26/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0687 - binary_accuracy: 0.9906 - val_loss: 0.1148 - val_binary_accuracy: 0.9720
# Epoch 27/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0662 - binary_accuracy: 0.9906 - val_loss: 0.1149 - val_binary_accuracy: 0.9626
# Epoch 28/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0636 - binary_accuracy: 0.9906 - val_loss: 0.1138 - val_binary_accuracy: 0.9720
# Epoch 29/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0612 - binary_accuracy: 0.9906 - val_loss: 0.1143 - val_binary_accuracy: 0.9626
# Epoch 30/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0591 - binary_accuracy: 0.9906 - val_loss: 0.1146 - val_binary_accuracy: 0.9626
# Epoch 31/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0571 - binary_accuracy: 0.9906 - val_loss: 0.1158 - val_binary_accuracy: 0.9626
# Epoch 32/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0551 - binary_accuracy: 0.9937 - val_loss: 0.1155 - val_binary_accuracy: 0.9626
# Epoch 33/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0531 - binary_accuracy: 0.9937 - val_loss: 0.1166 - val_binary_accuracy: 0.9533
# Epoch 34/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0515 - binary_accuracy: 0.9906 - val_loss: 0.1162 - val_binary_accuracy: 0.9533
# Epoch 35/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0499 - binary_accuracy: 0.9937 - val_loss: 0.1170 - val_binary_accuracy: 0.9533
# Epoch 36/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0484 - binary_accuracy: 0.9937 - val_loss: 0.1176 - val_binary_accuracy: 0.9533
# Epoch 37/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0469 - binary_accuracy: 0.9937 - val_loss: 0.1185 - val_binary_accuracy: 0.9533
# Epoch 38/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0456 - binary_accuracy: 0.9937 - val_loss: 0.1194 - val_binary_accuracy: 0.9533
# Epoch 39/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0442 - binary_accuracy: 0.9937 - val_loss: 0.1211 - val_binary_accuracy: 0.9533
# Epoch 40/70
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0433 - binary_accuracy: 0.9937 - val_loss: 0.1222 - val_binary_accuracy: 0.9533
# Epoch 41/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0418 - binary_accuracy: 0.9937 - val_loss: 0.1228 - val_binary_accuracy: 0.9533
# Epoch 42/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0409 - binary_accuracy: 0.9937 - val_loss: 0.1245 - val_binary_accuracy: 0.9533
# Epoch 43/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0397 - binary_accuracy: 0.9937 - val_loss: 0.1252 - val_binary_accuracy: 0.9533
# Epoch 44/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0388 - binary_accuracy: 0.9937 - val_loss: 0.1257 - val_binary_accuracy: 0.9533
# Epoch 45/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0379 - binary_accuracy: 0.9969 - val_loss: 0.1274 - val_binary_accuracy: 0.9533
# Epoch 46/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0371 - binary_accuracy: 0.9969 - val_loss: 0.1284 - val_binary_accuracy: 0.9533
# Epoch 47/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0361 - binary_accuracy: 0.9969 - val_loss: 0.1296 - val_binary_accuracy: 0.9533
# Epoch 48/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0355 - binary_accuracy: 0.9969 - val_loss: 0.1312 - val_binary_accuracy: 0.9533
# Epoch 49/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0347 - binary_accuracy: 0.9969 - val_loss: 0.1315 - val_binary_accuracy: 0.9533
# Epoch 50/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0339 - binary_accuracy: 0.9969 - val_loss: 0.1330 - val_binary_accuracy: 0.9533
# Epoch 51/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0331 - binary_accuracy: 0.9969 - val_loss: 0.1346 - val_binary_accuracy: 0.9533
# Epoch 52/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0326 - binary_accuracy: 0.9969 - val_loss: 0.1360 - val_binary_accuracy: 0.9626
# Epoch 53/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0318 - binary_accuracy: 0.9969 - val_loss: 0.1372 - val_binary_accuracy: 0.9533
# Epoch 54/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0312 - binary_accuracy: 0.9969 - val_loss: 0.1381 - val_binary_accuracy: 0.9533
# Epoch 55/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0307 - binary_accuracy: 0.9969 - val_loss: 0.1394 - val_binary_accuracy: 0.9626
# Epoch 56/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0301 - binary_accuracy: 0.9969 - val_loss: 0.1419 - val_binary_accuracy: 0.9533
# Epoch 57/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0292 - binary_accuracy: 0.9969 - val_loss: 0.1425 - val_binary_accuracy: 0.9533
# Epoch 58/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0285 - binary_accuracy: 0.9969 - val_loss: 0.1429 - val_binary_accuracy: 0.9626
# Epoch 59/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0278 - binary_accuracy: 0.9969 - val_loss: 0.1452 - val_binary_accuracy: 0.9533
# Epoch 60/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0270 - binary_accuracy: 0.9969 - val_loss: 0.1474 - val_binary_accuracy: 0.9626
# Epoch 61/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0260 - binary_accuracy: 0.9969 - val_loss: 0.1481 - val_binary_accuracy: 0.9626
# Epoch 62/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0251 - binary_accuracy: 0.9969 - val_loss: 0.1506 - val_binary_accuracy: 0.9626
# Epoch 63/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0238 - binary_accuracy: 0.9969 - val_loss: 0.1509 - val_binary_accuracy: 0.9626
# Epoch 64/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0225 - binary_accuracy: 0.9969 - val_loss: 0.1540 - val_binary_accuracy: 0.9626
# Epoch 65/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0206 - binary_accuracy: 0.9969 - val_loss: 0.1549 - val_binary_accuracy: 0.9533
# Epoch 66/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0197 - binary_accuracy: 0.9969 - val_loss: 0.1595 - val_binary_accuracy: 0.9533
# Epoch 67/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0181 - binary_accuracy: 0.9969 - val_loss: 0.1610 - val_binary_accuracy: 0.9533
# Epoch 68/70
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0167 - binary_accuracy: 0.9969 - val_loss: 0.1600 - val_binary_accuracy: 0.9533
# Epoch 69/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0159 - binary_accuracy: 0.9969 - val_loss: 0.1612 - val_binary_accuracy: 0.9533
# Epoch 70/70
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0152 - binary_accuracy: 1.0000 - val_loss: 0.1642 - val_binary_accuracy: 0.9533

# %%
y_val_loss = history.history['val_loss']

plt.plot(x_len,y_loss, marker='.', c="blue", label='Train-set loss')
plt.plot(x_len,y_val_loss, marker='.', c="red",label='Validation-set loss')

plt.legend(loc='upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
y_accu = history.history['binary_accuracy']
y_val_accu = history.history['val_binary_accuracy']

plt.plot(x_len,y_accu, marker='.', c="blue", label='Train-set accuracy')
plt.plot(x_len,y_val_accu, marker='.', c="red",label='Validation-set accuracy')

plt.legend(loc='upper right')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# **Early Stopping을 위해서**
#
# **from tensorflow.keras.callback inport ModelCheckpint, EarlyStopping**
#
# **를 사용한다.**

# %%
model.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0955 - binary_accuracy: 0.9790
# [0.09554629027843475, 0.9790209531784058]

# %% [markdown]
# # **3. Soft-max를 사용한 다중분류**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import random



random.seed(5)

Url_iris="https://raw.githubusercontent.com/gundaminpde/2022/main/iris.csv"


# 아이리스 데이터를 불러옵니다.
df_iris = pd.read_csv(Url_iris)

# %%
df_iris.head()
# Out:
#    ID  Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0   1           5.1          3.5           1.4          0.2  setosa
# 1   2           4.9          3.0           1.4          0.2  setosa
# 2   3           4.7          3.2           1.3          0.2  setosa
# 3   4           4.6          3.1           1.5          0.2  setosa
# 4   5           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            150 non-null    int64
#  1   Sepal_Length  150 non-null    float64
#  2   Sepal_Width   150 non-null    float64
#  3   Petal_Length  150 non-null    float64
#  4   Petal_Width   150 non-null    float64
#  5   Species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
X_iris=df_iris.iloc[:,1:5]
y_iris_string=df_iris.iloc[:,5]

# %%
y_iris= pd.get_dummies(y_iris_string)
y_iris.head()
# Out:
#    setosa  versicolor  virginica
# 0       1           0          0
# 1       1           0          0
# 2       1           0          0
# 3       1           0          0
# 4       1           0          0

# %%
model_iris = Sequential()
model_iris.add(Dense(10, input_dim=4, activation='relu'))
model_iris.add(Dense(10, activation='sigmoid'))
model_iris.add(Dense(3, activation='softmax'))
model_iris.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 10)                50
#
#  dense_10 (Dense)            (None, 10)                110
#
#  dense_11 (Dense)            (None, 3)                 33
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_iris.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history=model_iris.fit(X_iris, y_iris, epochs=50, batch_size=5)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 1s 2ms/step - loss: 1.1560 - accuracy: 0.3333
# Epoch 2/50
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1254 - accuracy: 0.3333
# Epoch 3/50
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1034 - accuracy: 0.3333
# Epoch 4/50
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0808 - accuracy: 0.3867
# Epoch 5/50
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0542 - accuracy: 0.6667
# Epoch 6/50
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0227 - accuracy: 0.6667
# Epoch 7/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9931 - accuracy: 0.6533
# Epoch 8/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.9655 - accuracy: 0.6533
# Epoch 9/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.9366 - accuracy: 0.5733
# Epoch 10/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.9072 - accuracy: 0.6467
# Epoch 11/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.8776 - accuracy: 0.6133
# Epoch 12/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.8449 - accuracy: 0.6533
# Epoch 13/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.8129 - accuracy: 0.6600
# Epoch 14/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.7834 - accuracy: 0.6867
# Epoch 15/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.7540 - accuracy: 0.6667
# Epoch 16/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.7253 - accuracy: 0.6733
# Epoch 17/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6996 - accuracy: 0.7533
# Epoch 18/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6757 - accuracy: 0.9267
# Epoch 19/50
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6548 - accuracy: 0.8267
# Epoch 20/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6335 - accuracy: 0.9400
# Epoch 21/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6159 - accuracy: 0.8933
# Epoch 22/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5998 - accuracy: 0.9133
# Epoch 23/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.9467
# Epoch 24/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5662 - accuracy: 0.9467
# Epoch 25/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.9533
# Epoch 26/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5351 - accuracy: 0.9467
# Epoch 27/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5208 - accuracy: 0.9733
# Epoch 28/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5070 - accuracy: 0.9733
# Epoch 29/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4951 - accuracy: 0.9800
# Epoch 30/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.9467
# Epoch 31/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4707 - accuracy: 0.9667
# Epoch 32/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4591 - accuracy: 0.9733
# Epoch 33/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4488 - accuracy: 0.9467
# Epoch 34/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.9733
# Epoch 35/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.9667
# Epoch 36/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.9600
# Epoch 37/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4035 - accuracy: 0.9733
# Epoch 38/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3954 - accuracy: 0.9667
# Epoch 39/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3841 - accuracy: 0.9600
# Epoch 40/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3739 - accuracy: 0.9667
# Epoch 41/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.9600
# Epoch 42/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3531 - accuracy: 0.9800
# Epoch 43/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3431 - accuracy: 0.9733
# Epoch 44/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3394 - accuracy: 0.9467
# Epoch 45/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.9533
# Epoch 46/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3170 - accuracy: 0.9800
# Epoch 47/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3107 - accuracy: 0.9733
# Epoch 48/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3069 - accuracy: 0.9667
# Epoch 49/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2938 - accuracy: 0.9667
# Epoch 50/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2826 - accuracy: 0.9800

# %% [markdown]
# # **4. 모델 저장과 재사용**

# %%
model_iris.save('./data/model/my_model.hdf5')

# %%
del model_iris

# %%
model_iris
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-8af7559fa3d8> in <module>
# ----> 1 model_iris
#
# NameError: name 'model_iris' is not defined

# %%
from tensorflow.keras.models import load_model


model_iris = load_model('./data/model/my_model.hdf5')

# %%
model_iris

# %% [markdown]
# # **5. Early Stopping**

# %%
### Breast%20Cancer_Wisconsin data의 전처리


import pandas as pd
import numpy as np
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import random

random.seed(5)

Url_B_cancer="https://raw.githubusercontent.com/gundaminpde/2023-spring/main/Dset_Breast%20Cancer_Wisconsin.csv"


df = pd.read_csv(Url_B_cancer)


df=df.drop(['id',"Unnamed: 32"],axis=1)
y_original = df['diagnosis']
y_original_2=pd.get_dummies(y_original)


X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:,1:], y_original_2['B'],stratify=y_original_2['B'], random_state=3)


std = StandardScaler()
std.fit(X_train.iloc[:,0:])
X_train.iloc[:,0:]= std.transform(X_train.iloc[:,0:])
X_test.iloc[:,0:]= std.transform(X_test.iloc[:,0:])

# %%
## 모양 확인

X_train.shape
# Out:
# (426, 30)

# %%
y_train.shape
# Out:
# (426,)

# %%
## 모델 만들기, 출력은 0과 1사이

model = Sequential()
model.add(Dense(20, input_dim=30, activation='relu'))
model.add(Dense(20, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

model.compile(loss='mse', optimizer='adam', metrics=['binary_accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 20)                620
#
#  dense_13 (Dense)            (None, 20)                420
#
#  dense_14 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1,061
# Trainable params: 1,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
## EarlyStopping 부분

from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.models import load_model

import os

# 모델 최적화를 위한 설정 구간입니다.
MODEL_DIR = './data/model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./data/model/Iris.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# 모델을 실행합니다.
history = model.fit(X_train, y_train, validation_split=0.1, epochs=100, batch_size=30, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1: val_loss improved from inf to 0.35093, saving model to ./data/model/Iris.hdf5
#
# Epoch 2: val_loss improved from 0.35093 to 0.29991, saving model to ./data/model/Iris.hdf5
#
# Epoch 3: val_loss improved from 0.29991 to 0.25063, saving model to ./data/model/Iris.hdf5
#
# Epoch 4: val_loss improved from 0.25063 to 0.20353, saving model to ./data/model/Iris.hdf5
#
# Epoch 5: val_loss improved from 0.20353 to 0.16276, saving model to ./data/model/Iris.hdf5
#
# Epoch 6: val_loss improved from 0.16276 to 0.13162, saving model to ./data/model/Iris.hdf5
#
# Epoch 7: val_loss improved from 0.13162 to 0.10869, saving model to ./data/model/Iris.hdf5
#
# Epoch 8: val_loss improved from 0.10869 to 0.09245, saving model to ./data/model/Iris.hdf5
#
# Epoch 9: val_loss improved from 0.09245 to 0.08055, saving model to ./data/model/Iris.hdf5
#
# Epoch 10: val_loss improved from 0.08055 to 0.07086, saving model to ./data/model/Iris.hdf5
#
# Epoch 11: val_loss improved from 0.07086 to 0.06365, saving model to ./data/model/Iris.hdf5
#
# Epoch 12: val_loss improved from 0.06365 to 0.05762, saving model to ./data/model/Iris.hdf5
#
# Epoch 13: val_loss improved from 0.05762 to 0.05297, saving model to ./data/model/Iris.hdf5
#
# Epoch 14: val_loss improved from 0.05297 to 0.04870, saving model to ./data/model/Iris.hdf5
#
# Epoch 15: val_loss improved from 0.04870 to 0.04540, saving model to ./data/model/Iris.hdf5
#
# Epoch 16: val_loss improved from 0.04540 to 0.04234, saving model to ./data/model/Iris.hdf5
#
# Epoch 17: val_loss improved from 0.04234 to 0.03981, saving model to ./data/model/Iris.hdf5
#
# Epoch 18: val_loss improved from 0.03981 to 0.03755, saving model to ./data/model/Iris.hdf5
#
# Epoch 19: val_loss improved from 0.03755 to 0.03546, saving model to ./data/model/Iris.hdf5
#
# Epoch 20: val_loss improved from 0.03546 to 0.03367, saving model to ./data/model/Iris.hdf5
#
# Epoch 21: val_loss improved from 0.03367 to 0.03221, saving model to ./data/model/Iris.hdf5
#
# Epoch 22: val_loss improved from 0.03221 to 0.03083, saving model to ./data/model/Iris.hdf5
#
# Epoch 23: val_loss improved from 0.03083 to 0.02948, saving model to ./data/model/Iris.hdf5
#
# Epoch 24: val_loss improved from 0.02948 to 0.02837, saving model to ./data/model/Iris.hdf5
#
# Epoch 25: val_loss improved from 0.02837 to 0.02746, saving model to ./data/model/Iris.hdf5
#
# Epoch 26: val_loss improved from 0.02746 to 0.02655, saving model to ./data/model/Iris.hdf5
#
# Epoch 27: val_loss improved from 0.02655 to 0.02518, saving model to ./data/model/Iris.hdf5
#
# Epoch 28: val_loss improved from 0.02518 to 0.02484, saving model to ./data/model/Iris.hdf5
#
# Epoch 29: val_loss improved from 0.02484 to 0.02421, saving model to ./data/model/Iris.hdf5
#
# Epoch 30: val_loss improved from 0.02421 to 0.02351, saving model to ./data/model/Iris.hdf5
#
# Epoch 31: val_loss improved from 0.02351 to 0.02292, saving model to ./data/model/Iris.hdf5
#
# Epoch 32: val_loss improved from 0.02292 to 0.02220, saving model to ./data/model/Iris.hdf5
#
# Epoch 33: val_loss improved from 0.02220 to 0.02148, saving model to ./data/model/Iris.hdf5
#
# Epoch 34: val_loss improved from 0.02148 to 0.02144, saving model to ./data/model/Iris.hdf5
#
# Epoch 35: val_loss improved from 0.02144 to 0.02139, saving model to ./data/model/Iris.hdf5
#
# Epoch 36: val_loss improved from 0.02139 to 0.02088, saving model to ./data/model/Iris.hdf5
#
# Epoch 37: val_loss improved from 0.02088 to 0.02053, saving model to ./data/model/Iris.hdf5
#
# Epoch 38: val_loss improved from 0.02053 to 0.02009, saving model to ./data/model/Iris.hdf5
#
# Epoch 39: val_loss did not improve from 0.02009
#
# Epoch 40: val_loss improved from 0.02009 to 0.01999, saving model to ./data/model/Iris.hdf5
#
# Epoch 41: val_loss improved from 0.01999 to 0.01938, saving model to ./data/model/Iris.hdf5
#
# Epoch 42: val_loss improved from 0.01938 to 0.01903, saving model to ./data/model/Iris.hdf5
#
# Epoch 43: val_loss did not improve from 0.01903
#
# Epoch 44: val_loss improved from 0.01903 to 0.01888, saving model to ./data/model/Iris.hdf5
#
# Epoch 45: val_loss did not improve from 0.01888
#
# Epoch 46: val_loss improved from 0.01888 to 0.01842, saving model to ./data/model/Iris.hdf5
#
# Epoch 47: val_loss did not improve from 0.01842
#
# Epoch 48: val_loss improved from 0.01842 to 0.01840, saving model to ./data/model/Iris.hdf5
#
# Epoch 49: val_loss improved from 0.01840 to 0.01782, saving model to ./data/model/Iris.hdf5
#
# Epoch 50: val_loss did not improve from 0.01782
#
# Epoch 51: val_loss did not improve from 0.01782
#
# Epoch 52: val_loss did not improve from 0.01782
#
# Epoch 53: val_loss improved from 0.01782 to 0.01782, saving model to ./data/model/Iris.hdf5
#
# Epoch 54: val_loss improved from 0.01782 to 0.01780, saving model to ./data/model/Iris.hdf5
#
# Epoch 55: val_loss improved from 0.01780 to 0.01767, saving model to ./data/model/Iris.hdf5
#
# Epoch 56: val_loss improved from 0.01767 to 0.01750, saving model to ./data/model/Iris.hdf5
#
# Epoch 57: val_loss did not improve from 0.01750
#
# Epoch 58: val_loss improved from 0.01750 to 0.01713, saving model to ./data/model/Iris.hdf5
#
# Epoch 59: val_loss improved from 0.01713 to 0.01695, saving model to ./data/model/Iris.hdf5
#
# Epoch 60: val_loss did not improve from 0.01695
#
# Epoch 61: val_loss did not improve from 0.01695
#
# Epoch 62: val_loss improved from 0.01695 to 0.01669, saving model to ./data/model/Iris.hdf5
#
# Epoch 63: val_loss did not improve from 0.01669
#
# Epoch 64: val_loss did not improve from 0.01669
#
# Epoch 65: val_loss did not improve from 0.01669
#
# Epoch 66: val_loss did not improve from 0.01669
#
# Epoch 67: val_loss did not improve from 0.01669
#
# Epoch 68: val_loss did not improve from 0.01669
#
# Epoch 69: val_loss did not improve from 0.01669
#
# Epoch 70: val_loss did not improve from 0.01669
#
# Epoch 71: val_loss did not improve from 0.01669
#
# Epoch 72: val_loss did not improve from 0.01669

# %%
## 그림을 그려 보자.

# 검증셋과 학습셋의 오차를 저장합니다.
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# 그래프로 표현해 봅니다.
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시하겠습니다.
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
## 테스트도 해보고...

print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, y_test)[1]))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0126 - binary_accuracy: 0.9860
#
#  Test Accuracy: 0.9860

# %% [markdown]
#  **Accuarcy 기준(threshold=0.5)를 바꾸기 위해서는 아래를 참고하세요.**
#
# https://keras.io/api/metrics/accuracy_metrics/
#
# 예를 들어 이렇게...
#
#
# ```
# model.compile(optimizer='sgd',loss='mse',
#               metrics=[tf.keras.metrics.BinaryAccuracy(threshold=0.5)])
# ```
